# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df =pd.read_csv("main.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df['Actor']
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: str

# %%
df[['Film','Year']]
# Out:
#                         Film  Year
# 0                    Pathaan  2023
# 1            Tiger Zinda Hai  2017
# 2                     Dangal  2016
# 3                 Brahmastra  2022
# 4                  Padmaavat  2018
# 5                  Andhadhun  2018
# 6                      Stree  2018
# 7                        War  2019
# 8                 Good Newwz  2019
# 9          Bhool Bhulaiyaa 2  2022
# 10     Badrinath Ki Dulhania  2017
# 11  Uri: The Surgical Strike  2019

# %%
df[['Actor','IMDb']]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[0] #as series
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.iloc[0]# as dataframe
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.loc[0, "Actor"] ## Value at row 0, column 'Name'
# Out:
# 'Shah Rukh Khan'

# %%
df.iloc[0, 3]
# Out:
# 'Action'

# %%
df.loc[8,'IMDb']
# Out:
# np.float64(7.0)

# %%
df.iloc[8,5]#iloc starts from 0 index .
# Out:
# np.float64(7.0)

# %%
df.iloc[0:2,0:2]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df[df['IMDb']>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df.at[0,'Actor']
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[2,0]
# Out:
# 'Aamir Khan'

# %%
df[(df['IMDb']>6) &(df['Year']>2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df[(df['IMDb']>6) | (df['Year']>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# ...

# %%
import pandas as pd

# %%
df =pd.read_csv("main.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.query("Year > 2019 and IMDb > 6") # we can use only operator in words like and ,or etc.
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df.query("Actor == 'Ranveer Singh'")
# Out:
#            Actor       Film  Year       Genre  BoxOffice(INR Crore)  IMDb
# 4  Ranveer Singh  Padmaavat  2018  Historical                   585   7.0

# %%
df.query("2019<Year<=2023") #remember case-sensitive
# Out:
#             Actor               Film  Year          Genre  \
# 0  Shah Rukh Khan            Pathaan  2023         Action
# 3   Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9

# %%
#query return a copy ,not a view

# %%
df2 = df['Actor'],['IMDb']

# %%
df2
# Out:
# (0         Shah Rukh Khan
#  1            Salman Khan
#  2             Aamir Khan
#  3          Ranbir Kapoor
#  4          Ranveer Singh
#  5     Ayushmann Khurrana
#  6          Rajkummar Rao
#  7         Hrithik Roshan
#  8           Akshay Kumar
#  9          Kartik Aaryan
#  10          Varun Dhawan
#  11         Vicky Kaushal
#  Name: Actor, dtype: str,
#  ['IMDb'])

# %%
import pandas as pd

# %%
df2 =pd.read_csv("main.csv")

# %%
df2.loc[2,'Actor']="tanishk"

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2              tanishk                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...
