# %%
pip install beautifulsoup4 lxml
# firstly we install it
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 6.2 MB/s  0:00:016.3 MB/s eta 0:00:01:01
# ...
# Note: you may need to restart the kernel to use updated packages.
