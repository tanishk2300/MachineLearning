# %%
import requests

# %%
a= requests.get("https://books.toscrape.com/")

# %%
for i in range (1,51):
    a= requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open (f"htmls/page{i}.html", "w",encoding="utf")as f:
        f.write(a.text)
        print(f"Downloade page {i} succesfully ")
# Out:
# Downloade page 1 succesfully
# Downloade page 2 succesfully
# Downloade page 3 succesfully
# Downloade page 4 succesfully
# Downloade page 5 succesfully
# Downloade page 6 succesfully
# Downloade page 7 succesfully
# Downloade page 8 succesfully
# Downloade page 9 succesfully
# Downloade page 10 succesfully
# Downloade page 11 succesfully
# Downloade page 12 succesfully
# Downloade page 13 succesfully
# Downloade page 14 succesfully
# Downloade page 15 succesfully
# Downloade page 16 succesfully
# Downloade page 17 succesfully
# Downloade page 18 succesfully
# Downloade page 19 succesfully
# Downloade page 20 succesfully
# Downloade page 21 succesfully
# Downloade page 22 succesfully
# Downloade page 23 succesfully
# Downloade page 24 succesfully
# Downloade page 25 succesfully
# Downloade page 26 succesfully
# Downloade page 27 succesfully
# Downloade page 28 succesfully
# Downloade page 29 succesfully
# Downloade page 30 succesfully
# Downloade page 31 succesfully
# ...
